# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

# %%
x_alz_val = []
y_alz_val = []

# %%
def boudingbox(bbox,img):
    xmin, ymin, xmax, ymax = bbox
    roi = img[ymin:ymax,xmin:xmax]
    roi = cv2.resize(roi,(54,28))
    return roi

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[109.51, 551.38, 231.84, 667.5].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [65,5,90,23]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [83,15,100,35]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [90,30,115,55]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [95,55,115,80]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [80,80,100,105]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [60,85,80,115]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [40,80,60,115]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [25,70,50,100]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [15,55,35,80]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [15,35,40,55]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [35,20,55,40]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [45,0,75,20]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[169.0, 452.92, 419.1, 663.76].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox=[95,5,145,35]
xmin, ymin, xmax, ymax = bbox
roi = img1[ymin:ymax,xmin:xmax]

plt.figure()
plt.imshow(roi,cmap='gray')
plt.show()

# %%
bbox = [160,15,190,50]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [200,50,225,75]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [210,100,240,130]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [175,155,200,185]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [130,170,160,200]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [100,170,130,205]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [50,175,75,200]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [5,125,35,160]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [0,75,30,105]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [25,35,65,60]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [70,20,95,40]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [95,5,145,35]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[174.78, 118.09, 375.96, 336.26].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox=[85,0,115,25]
xmin, ymin, xmax, ymax = bbox
roi = img1[ymin:ymax,xmin:xmax]

plt.figure()
plt.imshow(roi,cmap='gray')
plt.show()

# %%
bbox = [145,5,170,30]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)


bbox = [175,45,195,65]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [175,160,195,180]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [145,185,170,210]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [30,190,110,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [35,190,55,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [0,170,30,200]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)


bbox = [10,20,50,45]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [85,0,115,25]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[176.9, 444.77, 380.83, 656.36].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [145,5,165,25]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)


bbox = [180,30,205,60]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [180,130,205,145]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [165,165,190,190]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [95,180,125,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [30,180,70,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [5,165,25,190]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)


bbox = [25,0,55,25]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[185.39, 408.46, 413.69, 672.6].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [150,40,175,60]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [175,70,195,90]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [185,100,210,125]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [180,150,205,180]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [150,175,180,205]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [100,200,130,240]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [45,195,75,250]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [25,150,50,195]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [0,120,40,150]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [20,85,55,105]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [40,40,75,65]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [95,10,130,40]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[187.21, 398.32, 425.93, 654.86].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox=[105,5,130,35]
xmin, ymin, xmax, ymax = bbox
roi = img1[ymin:ymax,xmin:xmax]

plt.figure()
plt.imshow(roi,cmap='gray')
plt.show()

# %%
bbox = [175,35,195,50]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [200,65,225,85]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [215,115,245,140]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [190,170,210,190]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [140,205,160,235]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [90,225,110,250]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [50,215,70,240]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [0,160,30,190]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [0,100,25,150]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [15,50,40,75]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [50,20,75,50]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [105,5,130,35]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[196.51, 117.66, 394.17, 329.25].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox=[80,0,110,20]
xmin, ymin, xmax, ymax = bbox
roi = img1[ymin:ymax,xmin:xmax]

plt.figure()
plt.imshow(roi,cmap='gray')
plt.show()

# %%
bbox = [130,0,145,25]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [165,20,185,45]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [180,60,200,90]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [180,120,200,145]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [150,170,175,195]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [95,185,120,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [45,180,65,225]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [10,150,40,185]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [0,110,20,140]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [0,60,20,90]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [25,15,55,40]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [80,0,110,20]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
img1 = cv2.imread("Clocks_alz/a drawing of a circle[199.69, 112.54, 387.61, 309.99].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox=[90,5,105,25]
xmin, ymin, xmax, ymax = bbox
roi = img1[ymin:ymax,xmin:xmax]

plt.figure()
plt.imshow(roi,cmap='gray')
plt.show()

# %%
bbox = [130,20,145,40]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(1)

bbox = [160,55,175,80]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(2)

bbox = [160,85,180,110]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(3)

bbox = [155,120,175,150]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(4)

bbox = [125,155,145,180]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(5)

bbox = [75,165,95,190]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(6)

bbox = [40,160,65,185]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(7)

bbox = [5,125,25,145]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(8)

bbox = [0,80,20,100]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(9)

bbox = [20,40,40,60]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(10)

bbox = [50,10,70,30]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(11)

bbox = [90,5,105,25]
x_alz_val.append(boudingbox(bbox,img1))
y_alz_val.append(12)

# %%
x_alz_val = np.array(x_alz_val, dtype='float32')
y_alz_val = np.array(y_alz_val)

# %%
print(len(x_alz_val))
# Out:
# 89

# %%
with open(os.path.join('Val', 'x_alz_val.pickle'), 'wb') as f:
    pickle.dump(x_alz_val, f)
with open(os.path.join('Val', 'y_alz_val.pickle'), 'wb') as f:
    pickle.dump(y_alz_val, f)
