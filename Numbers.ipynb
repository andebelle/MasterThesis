# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

# %%
x_val = []
y_val = []

# %%
img1 = cv2.imread("Clocks/a drawing of a circle[174.78, 118.09, 375.96, 336.26].jpeg",cv2.IMREAD_GRAYSCALE)
#img1=cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_MEAN_C)
#img1 =img1/255.0
#_, img1 = cv2.threshold(img1, 224, 255, cv2.THRESH_BINARY)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [15,20,45,45]
xmin, ymin, xmax, ymax = bbox
roi2 = img1[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='binary_r')
plt.colorbar()
plt.show()
roi2 = cv2.resize(roi2,(54,28))
x_val.append(roi2)
y_val.append(11)

bbox = [10,170,30,200]
xmin, ymin, xmax, ymax = bbox
roi2 = img1[ymin:ymax, xmin:xmax]
plt.imshow(roi2)
plt.show()
roi2 = cv2.resize(roi2,(54,28))
x_val.append(roi2)
y_val.append(8)

# %%
img2 = cv2.imread('Clocks/a drawing of a circle[185.01, 122.55, 377.64, 325.68].jpeg',cv2.IMREAD_GRAYSCALE)
#_,img2=cv2.threshold(img2,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#img2 = img2/255.0
#_, img2 = cv2.threshold(img2, 224,255, cv2.THRESH_BINARY)
plt.imshow(img2,cmap='gray')

# %%
bbox = [25,35,52,57]
xmin, ymin, xmax, ymax = bbox
roi2 = img2[ymin:ymax, xmin:xmax]
plt.imshow(roi2)
plt.show()
roi2 = cv2.resize(roi2,(54,28))
x_val.append(roi2)
y_val.append(10)

bbox = [75,12,100,30]
xmin, ymin, xmax, ymax = bbox
roi2 = img2[ymin:ymax, xmin:xmax]
plt.imshow(roi2)
plt.show()
roi2 = cv2.resize(roi2,(54,28))
x_val.append(roi2)
y_val.append(12)

# %%
img3 = cv2.imread('Clocks/a drawing of a circle[196.65, 125.76, 388.33, 319.62].jpeg',cv2.IMREAD_GRAYSCALE)
#img3=cv2.adaptiveThreshold(img3,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
#img3 = img3/255.0
#_, img3 = cv2.threshold(img3, 224,255, cv2.THRESH_BINARY)
plt.imshow(img3,cmap='gray')
plt.show()

# %%
bbox = [65,15,90,40]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(12)

bbox = [40,27,70,53]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(11)

bbox = [25,110,50,135]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(7)

bbox = [40,127,70,160]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(6)

bbox = [77,145,110,175]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(5)

bbox = [125,130,150,170]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(4)

bbox = [140,95,170,120]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(3)

bbox = [145,60,175,90]
xmin, ymin, xmax, ymax = bbox
roi3 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi3)
plt.show()
roi3 = cv2.resize(roi3,(54,28))
x_val.append(roi3)
y_val.append(2)

# %%
img4 = cv2.imread('Clocks/a drawing of a circle[198.96, 144.93, 376.84, 330.27].jpeg',cv2.IMREAD_GRAYSCALE)
#img4 = img4/255.0
#_, img4 = cv2.threshold(img4, 224,255, cv2.THRESH_BINARY)
plt.imshow(img4,cmap='gray')
plt.show()

# %%
bbox = [65,8,95,30]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(12)

bbox = [35,20,65,45]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(11)

bbox = [5,40,35,75]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(10)

bbox = [3,85,25,110]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(9)

bbox = [18,120,35,145]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(8)

bbox = [45,148,60,170]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(7)

bbox = [75,150,95,175]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(6)

bbox = [120,140,135,170]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(5)


bbox = [140,110,160,135]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(4)

bbox = [150,75,170,100]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(3)

bbox = [140,50,157,75]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(2)

bbox = [120,20,140,40]
xmin, ymin, xmax, ymax = bbox
roi4 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi4)
plt.show()
roi4 = cv2.resize(roi4,(54,28))
x_val.append(roi4)
y_val.append(1)

# %%
img5 = cv2.imread('Clocks/a drawing of a circle[199.69, 112.54, 387.61, 309.99].jpeg',cv2.IMREAD_GRAYSCALE)
#img5 = img5/255.0
#_, img5 = cv2.threshold(img5, 224,255, cv2.THRESH_BINARY)
plt.imshow(img5,cmap='gray')
plt.show()

# %%
bbox = [90,10,105,30]
xmin, ymin, xmax, ymax = bbox
roi5 = img5[ymin:ymax, xmin:xmax]
plt.imshow(roi5)
plt.show()
roi5 = cv2.resize(roi5,(54,28))
x_val.append(roi5)
y_val.append(12)

bbox = [125,20,145,40]
xmin, ymin, xmax, ymax = bbox
roi5 = img5[ymin:ymax, xmin:xmax]
plt.imshow(roi5)
plt.show()
roi5 = cv2.resize(roi5,(54,28))
x_val.append(roi5)
y_val.append(1)

# %%
img6 = cv2.imread('Clocks/a drawing of a circle[200.44, 124.73, 393.56, 347.7].jpeg',cv2.IMREAD_GRAYSCALE)
#img6 = img6/255.0
#_, img6 = cv2.threshold(img6, 224,255, cv2.THRESH_BINARY)
plt.imshow(img6,cmap='gray')
plt.show()

# %%
bbox = [70,0,105,30]
xmin, ymin, xmax, ymax = bbox
roi6 = img6[ymin:ymax, xmin:xmax]
plt.imshow(roi6)
plt.show()
roi6 = cv2.resize(roi6,(54,28))
x_val.append(roi6)
y_val.append(12)

bbox = [30,5,60,30]
xmin, ymin, xmax, ymax = bbox
roi6 = img6[ymin:ymax, xmin:xmax]
plt.imshow(roi6)
plt.show()
roi6 = cv2.resize(roi6,(54,28))
x_val.append(roi6)
y_val.append(11)

bbox = [40,195,60,250]
xmin, ymin, xmax, ymax = bbox
roi6 = img6[ymin:ymax, xmin:xmax]
plt.imshow(roi6)
plt.show()
roi6 = cv2.resize(roi6,(54,28))
x_val.append(roi6)
y_val.append(7)

# %%
img7 = cv2.imread('Clocks/a drawing of a circle[202.91, 123.71, 383.84, 322.03].jpeg',cv2.IMREAD_GRAYSCALE)
#img7 = img7/255.0
#_, img7 = cv2.threshold(img7, 224,255, cv2.THRESH_BINARY)
plt.imshow(img7, cmap='gray')
plt.show()

# %%
bbox = [30,5,60,30]
xmin, ymin, xmax, ymax = bbox
roi7 = img7[ymin:ymax, xmin:xmax]
plt.imshow(roi7)
plt.show()
roi7 = cv2.resize(roi7,(54, 28))
x_val.append(roi7)
y_val.append(11)

# %%
img8 = cv2.imread('Clocks/a drawing of a circle[203.32, 121.52, 389.02, 316.42].jpeg',cv2.IMREAD_GRAYSCALE)
#img8 = img8/255.0
#_, img8 = cv2.threshold(img8, 224,255, cv2.THRESH_BINARY)
plt.imshow(img8,cmap='gray')
plt.show()

# %%
bbox = [75,10,105,35]
xmin, ymin, xmax, ymax = bbox
roi8 = img8[ymin:ymax, xmin:xmax]
plt.imshow(roi8)
plt.show()
roi8 = cv2.resize(roi8,(54,28))
x_val.append(roi8)
y_val.append(12)

bbox = [35,20,70,40]
xmin, ymin, xmax, ymax = bbox
roi8 = img8[ymin:ymax, xmin:xmax]
plt.imshow(roi8)
plt.show()
roi8 = cv2.resize(roi8,(54,28))
x_val.append(roi8)
y_val.append(11)

bbox = [5,60,30,78]
xmin, ymin, xmax, ymax = bbox
roi8 = img8[ymin:ymax, xmin:xmax]
plt.imshow(roi8)
plt.show()
roi8 = cv2.resize(roi8,(54,28))
x_val.append(roi8)
y_val.append(10)

# %%
img9 = cv2.imread('Clocks/Outputa drawing of a clock[214.97, 163.8, 387.64, 337.46].jpeg',cv2.IMREAD_GRAYSCALE)
#img9 = img9/255.0
#_, img9 = cv2.threshold(img9,224,255, cv2.THRESH_BINARY)
plt.imshow(img9, cmap='gray')
plt.show()

# %%
bbox = [115,18,135,35]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(1)

bbox = [130,30,165,62]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(2)

bbox = [135,95,160,120]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(4)

bbox = [120,130,140,150]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(5)

bbox = [70,145,100,165]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(6)

bbox = [25,130,55,160]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(7)

bbox = [10,105,35,125]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(8)

bbox = [2,65,35,95]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(9)

bbox = [75,5,95,25]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(12)

bbox = [30,15,50,30]
xmin, ymin, xmax, ymax = bbox
roi9 = img9[ymin:ymax, xmin:xmax]
plt.imshow(roi9)
plt.show()
roi9 = cv2.resize(roi9,(54,28))
x_val.append(roi9)
y_val.append(11)

# %%
img10 = cv2.imread('Clocks/Outputa drawing of a clock[226.84, 427.34, 358.82, 553.9].jpeg',cv2.IMREAD_GRAYSCALE)
#img10=img10/255.0
#_, img10 = cv2.threshold(img10, 224,255, cv2.THRESH_BINARY)
plt.imshow(img10,cmap='gray')
plt.show()

# %%
bbox = [85,20,115,35]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(1)

bbox = [98,40,123,55]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(2)

bbox = [25,100,55,120]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(7)

bbox = [105,85,130,110]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(4)

bbox = [85,100,115,118]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(5)

bbox = [5,27,35,45]
xmin, ymin, xmax, ymax = bbox
roi10 = img10[ymin:ymax, xmin:xmax]
plt.imshow(roi10)
plt.show()
roi10 = cv2.resize(roi10,(54,28))
x_val.append(roi10)
y_val.append(10)

# %%
img11 = cv2.imread('Clocks/a drawing of a circle[216.26, 55.93, 329.83, 168.59].jpeg',cv2.IMREAD_GRAYSCALE)
#img11 = img11/255.0
#_, img11 = cv2.threshold(img11, 224,255, cv2.THRESH_BINARY)
plt.imshow(img11,cmap='gray')
plt.show()

# %%
bbox = [60,15,80,35]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(2)

bbox = [75,25,95,40]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(1)

bbox = [80,45,100,60]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(3)

bbox = [82,65,103,80]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(4)

bbox = [70,83,95,100]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(5)

bbox = [45,85,65,115]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(6)

bbox = [25,85,43,100]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(7)

bbox = [12,70,30,90]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(8)

bbox = [8,50,30,70]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(9)

bbox = [6,35,23,50]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(10)

bbox = [15,20,35,35]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(11)

bbox = [40,8,60,23]
xmin, ymin, xmax, ymax = bbox
roi11 = img11[ymin:ymax, xmin:xmax]
plt.imshow(roi11)
plt.show()
roi11 = cv2.resize(roi11,(54,28))
x_val.append(roi11)
y_val.append(12)

# %%
img12 = cv2.imread('Clocks/a drawing of a clock[206.21, 285.65, 405.49, 482.74].jpeg',cv2.IMREAD_GRAYSCALE)
#img12=img12/255.0
#_, img12 = cv2.threshold(img12, 224,255, cv2.THRESH_BINARY)
plt.imshow(img12, cmap='gray')
plt.show()

# %%
bbox = [120,25,150,55]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(1)

bbox = [135,57,175,85]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(2)

bbox = [150,98,190,120]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(3)

bbox = [140,125,175,155]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(4)

bbox = [115,155,165,178]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi11)
y_val.append(5)

bbox = [73,155,105,190]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(6)

bbox = [40,150,75,175]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(7)

bbox = [5,115,45,135]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(8)

bbox = [0,70,25,100]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(9)

bbox = [5,45,40,65]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(10)

bbox = [25,23,65,50]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(11)

bbox = [80,10,120,35]
xmin, ymin, xmax, ymax = bbox
roi12 = img12[ymin:ymax, xmin:xmax]
plt.imshow(roi12)
plt.show()
roi12 = cv2.resize(roi12,(54,28))
x_val.append(roi12)
y_val.append(12)

# %%
img13 = cv2.imread('Clocks/a drawing of a circle[192.26, 466.41, 368.72, 644.08].jpeg',cv2.IMREAD_GRAYSCALE)
#img13 = img13/255.0
#_, img13 = cv2.threshold(img13, 224,255, cv2.THRESH_BINARY)
plt.imshow(img13,cmap='gray')
plt.show()

# %%
bbox = [5,105,25,135]
xmin, ymin, xmax, ymax = bbox
roi13 = img13[ymin:ymax, xmin:xmax]
plt.imshow(roi13)
plt.show()
roi13 = cv2.resize(roi13,(54,28))
x_val.append(roi13)
y_val.append(8)

bbox = [23,13,60,35]
xmin, ymin, xmax, ymax = bbox
roi13 = img13[ymin:ymax, xmin:xmax]
plt.imshow(roi13)
plt.show()
roi13 = cv2.resize(roi13,(54,28))
x_val.append(roi13)
y_val.append(11)

bbox = [60,0,110,23]
xmin, ymin, xmax, ymax = bbox
roi13 = img13[ymin:ymax, xmin:xmax]
plt.imshow(roi13)
plt.show()
roi13 = cv2.resize(roi13,(54,28))
x_val.append(roi13)
y_val.append(12)

bbox = [90,140,120,175]
xmin, ymin, xmax, ymax = bbox
roi13 = img13[ymin:ymax, xmin:xmax]
plt.imshow(roi13)
plt.show()
roi13 = cv2.resize(roi13,(54,28))
x_val.append(roi13)
y_val.append(5)

# %%
img14 = cv2.imread('Clocks/a drawing of a clock[214.72, 159.61, 382.42, 330.58].jpeg',cv2.IMREAD_GRAYSCALE)
#img14 = img14/255.0
#_, img14 = cv2.threshold(img14, 224,255, cv2.THRESH_BINARY)
plt.imshow(img14,cmap='gray')
plt.show()

# %%
bbox = [10,50,40,70]
xmin, ymin, xmax, ymax = bbox
roi14 = img14[ymin:ymax, xmin:xmax]
plt.imshow(roi14)
plt.show()
roi14 = cv2.resize(roi14,(54,28))
x_val.append(roi14)
y_val.append(10)

bbox = [35,20,65,45]
xmin, ymin, xmax, ymax = bbox
roi14 = img14[ymin:ymax, xmin:xmax]
plt.imshow(roi14)
plt.show()
roi14 = cv2.resize(roi14,(54,28))
x_val.append(roi14)
y_val.append(11)

bbox = [70,3,95,38]
xmin, ymin, xmax, ymax = bbox
roi14 = img14[ymin:ymax, xmin:xmax]
plt.imshow(roi14)
plt.show()
roi14 = cv2.resize(roi14,(54,28))
x_val.append(roi14)
y_val.append(12)

bbox = [100,20,120,55]
xmin, ymin, xmax, ymax = bbox
roi14 = img14[ymin:ymax, xmin:xmax]
plt.imshow(roi14)
plt.show()
roi14 = cv2.resize(roi14,(54,28))
x_val.append(roi14)
y_val.append(1)

bbox = [18,110,40,138]
xmin, ymin, xmax, ymax = bbox
roi14 = img14[ymin:ymax, xmin:xmax]
plt.imshow(roi14)
plt.show()
roi14 = cv2.resize(roi14,(54,28))
x_val.append(roi14)
y_val.append(8)

# %%
print(len(x_val))
# Out:
# 83

# %%
x_val = np.array(x_val, dtype='float32')
y_val = np.array(y_val)

# %%
print(x_val.shape)
# Out:
# (83, 28, 54)

# %%
x_val = np.array(x_val, dtype='float32')
y_val = np.array(y_val)
with open(os.path.join('Val', 'x_val.pickle'), 'wb') as f:
    pickle.dump(x_val, f)
with open(os.path.join('Val', 'y_val.pickle'), 'wb') as f:
    pickle.dump(y_val, f)
