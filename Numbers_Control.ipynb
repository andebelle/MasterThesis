# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

# %%
x_control_val = []
y_control_val = []

# %%
def boudingbox(bbox,img):
    xmin, ymin, xmax, ymax = bbox
    roi = img[ymin:ymax,xmin:xmax]
    roi = cv2.resize(roi,(54,28))
    return roi

# %%
img1 = cv2.imread("Clocks_control/a drawing of a circle[190.77, 410.3, 369.4, 577.56].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img1,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [125,20,155,45]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(1)

bbox = [140,50,160,70]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(2)

bbox = [145,80,170,95]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(3)

bbox = [135,115,160,135]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(4)

bbox = [105,135,125,155]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(5)

bbox = [70,140,90,160]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(6)

bbox = [25,130,50,155]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(7)

bbox = [5,115,30,140]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(8)

bbox = [0,75,20,95]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(9)

bbox = [15,40,40,60]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(10)

bbox = [40,20,60,35]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(11)

bbox = [85,0,105,25]
x_control_val.append(boudingbox(bbox,img1))
y_control_val.append(12)

# %%
img2 = cv2.imread("Clocks_control/a drawing of a circle[187.85, 413.85, 405.51, 625.04].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [150,20,175,55]
xmin, ymin, xmax, ymax = bbox
roi2 = img2[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [150,20,175,55]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(1)

bbox = [185,45,220,75]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(2)

bbox = [185,85,220,120]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(3)

bbox = [175,125,200,160]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(4)

bbox = [150,160,180,185]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(5)

bbox = [105,180,130,210]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(6)

bbox = [65,160,95,200]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(7)

bbox = [30,140,55,170]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(8)

bbox = [10,85,45,120]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(9)

bbox = [20,45,55,70]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(10)

bbox = [60,20,80,45]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(11)

bbox = [105,0,130,30]
x_control_val.append(boudingbox(bbox,img2))
y_control_val.append(12)

# %%
img3 = cv2.imread("Clocks_control/a drawing of a circle[198.96, 144.93, 376.84, 330.27].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img3,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [65,5,100,25]
xmin, ymin, xmax, ymax = bbox
roi2 = img3[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [115,25,140,50]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(1)

bbox = [140,50,160,75]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(2)

bbox = [145,75,170,95]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(3)

bbox = [140,110,160,135]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(4)

bbox = [115,130,135,160]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(5)

bbox = [75,150,100,175]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(6)

bbox = [40,140,60,170]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(7)

bbox = [15,115,35,145]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(8)

bbox = [0,80,30,115]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(9)

bbox = [5,50,45,75]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(10)

bbox = [35,20,65,45]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(11)

bbox = [65,5,100,25]
x_control_val.append(boudingbox(bbox,img3))
y_control_val.append(12)

# %%
print(len(x_control_val))
# Out:
# 36

# %%
img4 = cv2.imread("Clocks_control/a drawing of a clock[207.13, 143.93, 383.68, 320.64].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img4,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [65,0,95,30]
xmin, ymin, xmax, ymax = bbox
roi2 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [100,10,125,35]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(1)

bbox = [130,35,160,60]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(2)

bbox = [140,70,170,100]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(3)

bbox = [130,105,170,135]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(4)

bbox = [110,135,135,165]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(5)

bbox = [75,140,100,175]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(6)

bbox = [30,130,60,170]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(7)

bbox = [10,100,35,140]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(8)

bbox = [0,70,25,100]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(9)

bbox = [10,40,40,65]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(10)

bbox = [35,10,60,40]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(11)

bbox = [65,0,95,30]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(12)

# %%
img4 = cv2.imread("Clocks_control/a drawing of a circle[211.7, 424.39, 408.84, 617.0].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img4,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [75,10,105,30]
xmin, ymin, xmax, ymax = bbox
roi2 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [125,15,145,35]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(1)

bbox = [155,50,175,70]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(2)

bbox = [165,80,185,110]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(3)

bbox = [155,140,175,165]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(4)

bbox = [125,160,140,180]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(5)

bbox = [80,170,95,195]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(6)

bbox = [25,155,45,175]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(7)

bbox = [5,125,20,145]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(8)

bbox = [0,80,20,105]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(9)

bbox = [15,45,30,70]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(10)

bbox = [35,15,60,30]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(11)

bbox = [75,10,105,30]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(12)

# %%
img4 = cv2.imread("Clocks_control/a drawing of a circle[212.85, 126.39, 396.74, 317.53].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img4,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [55,10,95,30]
xmin, ymin, xmax, ymax = bbox
roi2 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [85,10,120,40]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(1)

bbox = [125,30,155,60]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(2)

bbox = [145,60,170,90]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(3)

bbox = [155,100,175,125]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(4)

bbox = [130,145,160,170]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(5)

bbox = [80,155,120,190]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(6)

bbox = [40,150,60,180]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(7)

bbox = [10,125,30,160]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(8)

bbox = [0,90,25,120]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(9)

bbox = [0,50,30,80]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(10)

bbox = [30,20,55,40]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(11)

bbox = [55,10,95,30]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(12)

# %%
img4 = cv2.imread("Clocks_control/a drawing of a circle[248.97, 445.7, 413.55, 603.09].jpeg",cv2.IMREAD_GRAYSCALE)
plt.figure()
plt.imshow(img4,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [60,5,90,25]
xmin, ymin, xmax, ymax = bbox
roi2 = img4[ymin:ymax, xmin:xmax]
plt.imshow(roi2,cmap='gray')
plt.colorbar()
plt.show()

# %%
bbox = [115,15,135,35]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(1)

bbox = [140,40,160,65]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(2)

bbox = [140,75,160,95]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(3)

bbox = [135,115,150,135]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(4)

bbox = [100,135,120,155]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(5)

bbox = [70,130,85,155]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(6)

bbox = [30,115,40,140]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(7)

bbox = [5,90,25,115]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(8)

bbox = [0,60,20,85]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(9)

bbox = [0,50,30,80]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(10)

bbox = [20,5,40,30]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(11)

bbox = [60,5,90,25]
x_control_val.append(boudingbox(bbox,img4))
y_control_val.append(12)

# %%
x_control_val = np.array(x_control_val, dtype='float32')
y_control_val = np.array(y_control_val)

# %%
print(len(x_control_val))
# Out:
# 84

# %%
with open(os.path.join('Val', 'x_control_val.pickle'), 'wb') as f:
    pickle.dump(x_control_val, f)
with open(os.path.join('Val', 'y_control_val.pickle'), 'wb') as f:
    pickle.dump(y_control_val, f)
